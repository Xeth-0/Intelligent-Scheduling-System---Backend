# %%
# Genetic Algorithm Prototyping
# Going to be using this for the initial development of the scheduling algorithm.

# %%
# Make some sample data
from sampleData import SampleData

sampleData = SampleData()

rooms = sampleData.rooms
courses = sampleData.courses
teachers = sampleData.teachers
student_groups = sampleData.student_groups

# %%
from scheduling import GeneticScheduler

# Example usage:
def run_scheduling():
    # Sample timeslots and days (would come from real data)
    timeslots = ["08:00-09:30", "09:40-11:10", "11:20-12:50", "13:30-15:00", "15:10-16:40"]
    days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
    
    # Create scheduler
    scheduler = GeneticScheduler(
        courses=courses,
        teachers=teachers,
        rooms=rooms,
        student_groups=student_groups,
        timeslots=timeslots,
        days=days,
        population_size=50,
    )
    
    # Run the genetic algorithm
    best_schedule, best_fitness = scheduler.run(generations=100)
    
    # Print results
    print(f"Best schedule fitness: {best_fitness}")
    if best_schedule:
        for item in best_schedule:
            print(f"Course: {item.courseName}, Room: {item.classroomId}, Day: {item.day}, Time: {item.timeslot}")
    
    return best_schedule


res = run_scheduling()
# Out:
# Generation 0: New best fitness = 14000000.00
# Generation 1: New best fitness = 12000000.00
# Generation 3: New best fitness = 10002000.00
# Generation 4: New best fitness = 9004000.00
# Generation 5: New best fitness = 8005000.00
# Generation 6: New best fitness = 7012200.00
# Generation 7: New best fitness = 6008200.00
# Generation 8: New best fitness = 6005200.00
# Generation 9: New best fitness = 4009400.00
# Generation 10: New best fitness = 3010200.00
# Generation 12: New best fitness = 2012400.00
# Generation 13: New best fitness = 1015400.00
# Generation 14: New best fitness = 1013400.00
# Generation 15: New best fitness = 16600.00
# Generation 16: New best fitness = 15600.00
# Generation 17: New best fitness = 12400.00
# Generation 20: New best fitness = 10400.00
# Generation 21: New best fitness = 8400.00
# Generation 22: New best fitness = 8200.00
# Generation 23: New best fitness = 6200.00
# Generation 26: New best fitness = 5000.00
# Generation 27: New best fitness = 3000.00
# Generation 29: New best fitness = 0.00
# Perfect solution found! Generations: 29/100, Fitness: 0
# Best schedule fitness: 0
# Course: Fundamentals of Electrical Engineering(1)[lec-1]SG_Y1_SG_Y2, Room: 1, Day: Monday, Time: 15:10-16:40
# Course: Fundamentals of Electrical Engineering(1)[lab-1]SG_Y1_SG_Y2, Room: 4, Day: Friday, Time: 15:10-16:40
# Course: Fundamentals of Web Development(2)[lec-1]SG_Y1_SG_Y2, Room: 2, Day: Wednesday, Time: 11:20-12:50
# Course: Fundamentals of Web Development(2)[lab-1]SG_Y1_SG_Y2, Room: 4, Day: Thursday, Time: 11:20-12:50
# Course: Human Computer Interaction(3)[lec-1]SG_Y1, Room: 3, Day: , Time:
# Course: Human Computer Interaction(3)[lab-1]SG_Y1, Room: 4, Day: Wednesday, Time: 08:00-09:30
# Course: Software Engineering(4)[lec-1]SG_Y1, Room: 2, Day: Monday, Time: 13:30-15:00
# Course: Software Engineering(4)[lec-2]SG_Y2, Room: 1, Day: , Time: 13:30-15:00
# Course: Software Engineering(4)[lab-1]SG_Y1, Room: 5, Day: Friday, Time: 11:20-12:50
# Course: Software Engineering(4)[lab-2]SG_Y2, Room: 4, Day: Monday, Time: 11:20-12:50
# Course: Computer Architecture(5)[lec-1]SG_Y1_SG_Y2, Room: 2, Day: Tuesday, Time:
# Course: Computer Architecture(5)[lab-1]SG_Y1_SG_Y2, Room: 4, Day: Thursday, Time: 15:10-16:40
# Course: Artificial Intelligence(6)[lec-1]SG_Y2, Room: 2, Day: , Time:
# Course: Artificial Intelligence(6)[lab-1]SG_Y2, Room: 4, Day: Wednesday, Time: 13:30-15:00

# %%
rooms_dict = {room.classroomId: room for room in rooms}

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

def visualize_schedule(schedule, days, timeslots):
    """
    Visualize the schedule in a tabular format using pandas DataFrame
    Args:
        schedule: List[ScheduledItem] - The schedule to visualize
        days: List[str] - Days of the week
        timeslots: List[str] - Available timeslots
    """
    # Create empty timetable grid
    timetable = {day: {timeslot: "Free" for timeslot in timeslots} for day in days}
    
    # Fill in the timetable with scheduled items
    for item in schedule:
        if item.day in timetable and item.timeslot in timetable[item.day]:
            room = rooms_dict[item.classroomId]
            timetable[item.day][item.timeslot] += f"{item.courseName} ({room.name + ' (' + room.type + ')'})" + (
                " (Invalid)" if not item.is_valid_hard else ""
            )

    
    # Convert to pandas DataFrame for better visualization
    df = pd.DataFrame(timetable)
    df.index.name = 'Timeslot'
    
    return df

# Example usage with the run_scheduling function
def run_scheduling_with_visualization():
    # Sample timeslots and days (would come from real data)
    timeslots = ["08:00-09:30", "09:40-11:10", "13:30-15:00", "15:10-16:40"]
    days = ["Monday", "Tuesday", "Wednesday", "Thursday"]
    
    # Create scheduler
    scheduler = GeneticScheduler(
        courses=courses,
        teachers=teachers,
        rooms=rooms,
        timeslots=timeslots,
        student_groups=student_groups,
        days=days,
        population_size=50,
    )
    
    # Run the genetic algorithm
    best_schedule, best_fitness = scheduler.run()
    
    # Print results
    print(f"\nBest schedule fitness: {best_fitness}")
    if best_schedule:
        df = visualize_schedule(best_schedule, days, timeslots)
        # Optionally return the DataFrame for further analysis
        return best_schedule, df
    
    return best_schedule, None

# Run the scheduling with visualization
res, schedule_df = run_scheduling_with_visualization()
schedule_df
# Out:
# Generation 0: New best fitness = 14000000.00
# Generation 1: New best fitness = 13000000.00
# Generation 4: New best fitness = 11003000.00
# Generation 5: New best fitness = 10006200.00
# Generation 6: New best fitness = 9006000.00
# Generation 7: New best fitness = 9002000.00
# Generation 8: New best fitness = 8000000.00
# Generation 9: New best fitness = 7002000.00
# Generation 10: New best fitness = 5014000.00
# Generation 11: New best fitness = 5005000.00
# Generation 12: New best fitness = 4005000.00
# Generation 13: New best fitness = 3010200.00
# Generation 14: New best fitness = 2016000.00
# Generation 15: New best fitness = 1014000.00
# Generation 17: New best fitness = 15000.00
# Generation 18: New best fitness = 12000.00
# Generation 19: New best fitness = 9000.00
# Generation 22: New best fitness = 7000.00
# Generation 23: New best fitness = 5000.00
# Generation 26: New best fitness = 2000.00
# Generation 29: New best fitness = 1000.00
# Generation 35: New best fitness = 0.00
# Perfect solution found! Generations: 35/10000, Fitness: 0
#
# Best schedule fitness: 0
#                                                                                         Monday  \
# Timeslot
# 08:00-09:30                       FreeComputer Architecture(5)[lab-1]SG_Y1_SG_Y2 (NB114 (lab))
# 09:40-11:10             FreeFundamentals of Web Development(2)[lab-1]SG_Y1_SG_Y2 (NB114 (lab))
# 13:30-15:00                                                                               Free
# 15:10-16:40  FreeFundamentals of Electrical Engineering(1)[lec-1]SG_Y1_SG_Y2 (NB111 (lecture))
#
#                                                                                                                       Tuesday  \
# Timeslot
# 08:00-09:30  FreeHuman Computer Interaction(3)[lec-1]SG_Y1 (NB113 (lecture))Software Engineering(4)[lab-2]SG_Y2 (NB114 (lab))
# 09:40-11:10                                                          FreeArtificial Intelligence(6)[lab-1]SG_Y2 (NB114 (lab))
# 13:30-15:00                                                                                                              Free
# 15:10-16:40                                                                                                              Free
#
#                                                              Wednesday  \
# Timeslot
# 08:00-09:30  FreeSoftware Engineering(4)[lec-2]SG_Y2 (NB111 (lecture))
# 09:40-11:10                                                       Free
# 13:30-15:00                                                       Free
# 15:10-16:40                                                       Free
#
#                                                                                   Thursday
# Timeslot
# 08:00-09:30  FreeFundamentals of Electrical Engineering(1)[lab-1]SG_Y1_SG_Y2 (NB114 (lab))
# 09:40-11:10                      FreeSoftware Engineering(4)[lec-1]SG_Y1 (NB112 (lecture))
# 13:30-15:00     FreeFundamentals of Web Development(2)[lec-1]SG_Y1_SG_Y2 (NB111 (lecture))
# 15:10-16:40                                                                           Free

# %%
res
# Out:
# [ScheduledItem(courseId='1', courseName='Fundamentals of Electrical Engineering(1)[lec-1]SG_Y1_SG_Y2', sessionType='lecture', teacherId='1', studentGroupIds=['SG_Y1', 'SG_Y2'], classroomId='1', timeslot='15:10-16:40', day='Monday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='1', courseName='Fundamentals of Electrical Engineering(1)[lab-1]SG_Y1_SG_Y2', sessionType='lab', teacherId='1', studentGroupIds=['SG_Y1', 'SG_Y2'], classroomId='4', timeslot='08:00-09:30', day='Thursday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='2', courseName='Fundamentals of Web Development(2)[lec-1]SG_Y1_SG_Y2', sessionType='lecture', teacherId='2', studentGroupIds=['SG_Y1', 'SG_Y2'], classroomId='1', timeslot='13:30-15:00', day='Thursday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='2', courseName='Fundamentals of Web Development(2)[lab-1]SG_Y1_SG_Y2', sessionType='lab', teacherId='2', studentGroupIds=['SG_Y1', 'SG_Y2'], classroomId='4', timeslot='09:40-11:10', day='Monday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='3', courseName='Human Computer Interaction(3)[lec-1]SG_Y1', sessionType='lecture', teacherId='3', studentGroupIds=['SG_Y1'], classroomId='3', timeslot='08:00-09:30', day='Tuesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='3', courseName='Human Computer Interaction(3)[lab-1]SG_Y1', sessionType='lab', teacherId='3', studentGroupIds=['SG_Y1'], classroomId='4', timeslot='13:30-15:00', day='', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='4', courseName='Software Engineering(4)[lec-1]SG_Y1', sessionType='lecture', teacherId='4', studentGroupIds=['SG_Y1'], classroomId='2', timeslot='09:40-11:10', day='Thursday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='4', courseName='Software Engineering(4)[lec-2]SG_Y2', sessionType='lecture', teacherId='4', studentGroupIds=['SG_Y2'], classroomId='1', timeslot='08:00-09:30', day='Wednesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='4', courseName='Software Engineering(4)[lab-1]SG_Y1', sessionType='lab', teacherId='4', studentGroupIds=['SG_Y1'], classroomId='4', timeslot='', day='Tuesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='4', courseName='Software Engineering(4)[lab-2]SG_Y2', sessionType='lab', teacherId='4', studentGroupIds=['SG_Y2'], classroomId='4', timeslot='08:00-09:30', day='Tuesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='5', courseName='Computer Architecture(5)[lec-1]SG_Y1_SG_Y2', sessionType='lecture', teacherId='5', studentGroupIds=['SG_Y1', 'SG_Y2'], classroomId='2', timeslot='15:10-16:40', day='', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='5', courseName='Computer Architecture(5)[lab-1]SG_Y1_SG_Y2', sessionType='lab', teacherId='5', studentGroupIds=['SG_Y1', 'SG_Y2'], classroomId='4', timeslot='08:00-09:30', day='Monday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='6', courseName='Artificial Intelligence(6)[lec-1]SG_Y2', sessionType='lecture', teacherId='6', studentGroupIds=['SG_Y2'], classroomId='2', timeslot='', day='Thursday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='6', courseName='Artificial Intelligence(6)[lab-1]SG_Y2', sessionType='lab', teacherId='6', studentGroupIds=['SG_Y2'], classroomId='4', timeslot='09:40-11:10', day='Tuesday', is_valid_hard=True, is_valid_soft=True)]
