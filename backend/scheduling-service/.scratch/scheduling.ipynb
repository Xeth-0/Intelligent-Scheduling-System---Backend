# %%
# Genetic Algorithm Prototyping
# Going to be using this for the initial development of the scheduling algorithm.

# %%
# Make some sample data
from sampleData import SampleData

sampleData = SampleData()

rooms = sampleData.rooms
courses = sampleData.courses
teachers = sampleData.teachers
student_groups = sampleData.student_groups

# %%
from scheduling import GeneticScheduler

# Example usage:
def run_scheduling():
    # Sample timeslots and days (would come from real data)
    timeslots = ["08:00-09:30", "09:40-11:10", "11:20-12:50", "13:30-15:00", "15:10-16:40"]
    days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
    
    # Create scheduler
    scheduler = GeneticScheduler(
        courses=courses,
        teachers=teachers,
        rooms=rooms,
        student_groups=student_groups,
        timeslots=timeslots,
        days=days,
        population_size=50,
    )
    
    # Run the genetic algorithm
    best_schedule, best_fitness = scheduler.run(generations=100)
    
    # Print results
    print(f"Best schedule fitness: {best_fitness}")
    if best_schedule:
        for item in best_schedule:
            print(f"Course: {item.courseName}, Room: {item.classroomId}, Day: {item.day}, Time: {item.timeslot}")
    
    return best_schedule


res = run_scheduling()
# Out:
# Generation 0: New best fitness = 36000000.00
# Generation 1: New best fitness = 30008400.00
# Generation 2: New best fitness = 28004600.00
# Generation 3: New best fitness = 26010000.00
# Generation 4: New best fitness = 24020200.00
# Generation 5: New best fitness = 23020400.00
# Generation 6: New best fitness = 21022200.00
# Generation 7: New best fitness = 19020400.00
# Generation 8: New best fitness = 17018600.00
# Generation 10: New best fitness = 13031000.00
# Generation 11: New best fitness = 13029000.00
# Generation 12: New best fitness = 11029000.00
# Generation 13: New best fitness = 11026800.00
# Generation 14: New best fitness = 7054200.00
# Generation 16: New best fitness = 7031800.00
# Generation 17: New best fitness = 5051600.00
# Generation 18: New best fitness = 3049600.00
# Generation 19: New best fitness = 2031600.00
# Generation 21: New best fitness = 1036000.00
# Generation 22: New best fitness = 1035800.00
# Generation 23: New best fitness = 1032000.00
# Generation 24: New best fitness = 1029000.00
# Generation 26: New best fitness = 29200.00
# Generation 28: New best fitness = 26000.00
# Generation 29: New best fitness = 23000.00
# Generation 30: New best fitness = 20000.00
# Generation 31: New best fitness = 19800.00
# Generation 32: New best fitness = 19000.00
# Generation 33: New best fitness = 18600.00
# Generation 34: New best fitness = 15800.00
# Generation 35: New best fitness = 15600.00
# Generation 36: New best fitness = 14800.00
# Generation 37: New best fitness = 14600.00
# Generation 38: New best fitness = 14400.00
# Generation 39: New best fitness = 13400.00
# Generation 40: New best fitness = 11400.00
# Generation 41: New best fitness = 10400.00
# Generation 44: New best fitness = 9200.00
# Generation 46: New best fitness = 8200.00
# Generation 51: New best fitness = 7200.00
# Generation 52: New best fitness = 7000.00
# Generation 53: New best fitness = 6000.00
# Generation 54: New best fitness = 5000.00
# Generation 58: New best fitness = 4800.00
# Generation 62: New best fitness = 4600.00
# Generation 66: New best fitness = 4400.00
# Generation 78: New best fitness = 2200.00
# Generation 81: New best fitness = 1000.00
# Generation 85: New best fitness = 800.00
# Generation 88: New best fitness = 600.00
# Generation 91: New best fitness = 400.00
# Generation 95: New best fitness = 200.00
# Generation 99: New best fitness = 0.00
# Perfect solution found! Generations: 99/100, Fitness: 0
# Best schedule fitness: 0
# Course: Fundamental of Electrical Circuits and Electronics [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4, Room: 1, Day: Friday, Time: 13:30-15:00
# Course: Fundamental of Electrical Circuits and Electronics [lab - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4, Room: 4, Day: Thursday, Time: 08:00-09:30
# Course: Computer Architecture and Organization [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4, Room: 1, Day: Wednesday, Time: 13:30-15:00
# Course: Web Design and Development [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4, Room: 1, Day: Thursday, Time:
# Course: Web Design and Development [lab - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4, Room: 4, Day: Tuesday, Time: 09:40-11:10
# Course: Human Computer Interaction [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4, Room: 1, Day: , Time: 09:40-11:10
# Course: Fundamentals of Software Engineering [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4, Room: 1, Day: Tuesday, Time: 08:00-09:30
# Course: Fundamentals of Software Engineering [lab - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4, Room: 4, Day: Monday, Time: 08:00-09:30
# Course: Software Project Management [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2, Room: 2, Day: Monday, Time: 09:40-11:10
# Course: Software Project Management [lec - 2] SG_Y4_AI, Room: 1, Day: Monday, Time: 08:00-09:30
# Course: Enterprise Application Development [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2, Room: 2, Day: Wednesday, Time: 08:00-09:30
# Course: Enterprise Application Development [lab - 1] SG_Y4_SE_S1|SG_Y4_SE_S2, Room: 4, Day: Friday, Time: 13:30-15:00
# Course: Requirement Engineering, Architecture and Design [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2, Room: 1, Day: Friday, Time: 15:10-16:40
# Course: History of Ethiopia and the Horn [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2|SG_Y4_AI|SG_Y4_CY|SG_Y4_IT, Room: 1, Day: Thursday, Time: 09:40-11:10
# Course: Fundamentals of Distributed Systems [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2, Room: 2, Day: Monday, Time: 08:00-09:30
# Course: Machine Learning and Big Data [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2|SG_Y4_CY, Room: 1, Day: Wednesday, Time: 15:10-16:40
# Course: Machine Learning and Big Data [lab - 1] SG_Y4_SE_S1|SG_Y4_SE_S2|SG_Y4_CY, Room: 4, Day: , Time:
# Course: Machine Learning [lec - 1] SG_Y4_AI, Room: 2, Day: Friday, Time: 13:30-15:00
# Course: Machine Learning [lab - 1] SG_Y4_AI, Room: 4, Day: Friday, Time: 09:40-11:10
# Course: Social Network Analysis [lec - 1] SG_Y4_AI, Room: 2, Day: Tuesday, Time: 13:30-15:00
# Course: Mathematics for AI [lec - 1] SG_Y4_AI, Room: 2, Day: Monday, Time:
# Course: Introduction to Robotics and Intelligent Systems [lec - 1] SG_Y4_AI, Room: 1, Day: , Time: 15:10-16:40
# Course: Introduction to Robotics and Intelligent Systems [lab - 1] SG_Y4_AI, Room: 4, Day: Friday, Time: 08:00-09:30
# Course: Enterprise Systems and Network Security [lec - 1] SG_Y4_CY, Room: 1, Day: Thursday, Time: 08:00-09:30
# Course: Enterprise Systems and Network Security [lab - 1] SG_Y4_CY, Room: 4, Day: Monday, Time: 15:10-16:40
# Course: Cloud Computing Security [lec - 1] SG_Y4_CY, Room: 2, Day: Monday, Time: 13:30-15:00
# Course: Enterprise Systems and Network Administration [lec - 1] SG_Y4_IT, Room: 2, Day: Wednesday, Time: 11:20-12:50
# Course: Enterprise Systems and Network Administration [lab - 1] SG_Y4_IT, Room: 4, Day: Tuesday, Time: 13:30-15:00
# Course: E-business Strategy and Development [lec - 1] SG_Y4_IT, Room: 2, Day: Tuesday, Time: 09:40-11:10
# Course: Database Administration and Security [lec - 1] SG_Y4_IT, Room: 1, Day: Wednesday, Time:
# Course: Database Administration and Security [lab - 1] SG_Y4_IT, Room: 4, Day: Wednesday, Time: 09:40-11:10
# Course: Big Data Modeling and Management System [lec - 1] SG_Y5_S1|SG_Y5_S2, Room: 2, Day: , Time: 09:40-11:10
# Course: Distributed and Object Database [lec - 1] SG_Y5_S1|SG_Y5_S2, Room: 2, Day: Monday, Time: 15:10-16:40
# Course: Distributed and Object Database [lab - 1] SG_Y5_S1|SG_Y5_S2, Room: 4, Day: Tuesday, Time: 15:10-16:40
# Course: Introduction to Robotics [lec - 1] SG_Y5_S1|SG_Y5_S2, Room: 2, Day: Friday, Time:
# Course: Introduction to Robotics [lab - 1] SG_Y5_S1|SG_Y5_S2, Room: 4, Day: Wednesday, Time: 08:00-09:30

# %%
rooms_dict = {room.classroomId: room for room in rooms}

# %%
from IPython.display import display, HTML
import pandas as pd
pd.set_option('display.max_colwidth', None)

def visualize_schedule(schedule, days, timeslots):
    """
    Visualize the schedule in a tabular format using pandas DataFrame
    Args:
        schedule: List[ScheduledItem] - The schedule to visualize
        days: List[str] - Days of the week
        timeslots: List[str] - Available timeslots
    Returns:
        Tuple[pd.DataFrame, Dict[str, pd.DataFrame]] - Overall timetable and per-group timetables
    """
    # Create empty timetable grid for overall schedule
    timetable = {day: {timeslot: "Free" for timeslot in timeslots} for day in days}
    
    # Create empty timetable grids for each student group
    student_group_timetables = {}
    all_student_groups = set()
    for item in schedule:
        all_student_groups.update(item.studentGroupIds)
    
    for sg in all_student_groups:
        student_group_timetables[sg] = {
            day: {timeslot: "Free" for timeslot in timeslots} for day in days
        }
    
    # Fill in the timetables with scheduled items
    for item in schedule:
        if item.day in timetable and item.timeslot in timetable[item.day]:
            room = rooms_dict[item.classroomId]
            schedule_text = f"{item.courseName}<br>({room.name + ' (' + room.type + ')'})" + (
                " (Invalid) <br><br>" if not item.is_valid_hard else "<br><br>"
            )
            
            # Update overall timetable
            if timetable[item.day][item.timeslot] == "Free":
                timetable[item.day][item.timeslot] = ""
            timetable[item.day][item.timeslot] += schedule_text
            
            # Update student group timetables
            for sg_id in item.studentGroupIds:
                if student_group_timetables[sg_id][item.day][item.timeslot] == "Free":
                    student_group_timetables[sg_id][item.day][item.timeslot] = ""
                student_group_timetables[sg_id][item.day][item.timeslot] += schedule_text

    # Convert to pandas DataFrames
    overall_df = pd.DataFrame(timetable)
    overall_df.index.name = 'Timeslot'
    
    group_dfs = {}
    for sg_id, sg_timetable in student_group_timetables.items():
        group_df = pd.DataFrame(sg_timetable)
        group_df.index.name = 'Timeslot'
        group_dfs[sg_id] = group_df
    
    return overall_df, group_dfs

# Example usage with the run_scheduling function
def run_scheduling_with_visualization():
    # Sample timeslots and days (would come from real data)
    timeslots = ["08:00-09:30", "09:40-11:10", "11:20-12:50", "13:30-15:00", "15:10-16:40"]
    days = ["Monday", "Tuesday", "Wednesday"]
    
    # Create scheduler
    scheduler = GeneticScheduler(
        courses=courses,
        teachers=teachers,
        rooms=rooms,
        timeslots=timeslots,
        student_groups=student_groups,
        days=days,
        population_size=50,
    )
    
    # Run the genetic algorithm
    best_schedule, best_fitness = scheduler.run()
    
    # Print results
    print(f"\nBest schedule fitness: {best_fitness}")
    if best_schedule:
        overall_df, group_dfs = visualize_schedule(best_schedule, days, timeslots)
        # Optionally return the DataFrame for further analysis
        return best_schedule, overall_df, group_dfs
    
    return best_schedule, None

# Run the scheduling with visualization
res, schedule_df, group_dfs = run_scheduling_with_visualization()
display(HTML(schedule_df.to_html(escape=False)))
display(HTML(group_dfs['SG_Y4_SE_S1'].to_html(escape=False)))
# Out:
# Generation 0: New best fitness = 36000000.00
# Generation 1: New best fitness = 35000000.00
# Generation 2: New best fitness = 32004000.00
# Generation 3: New best fitness = 30000400.00
# Generation 4: New best fitness = 27002400.00
# Generation 5: New best fitness = 24010400.00
# Generation 6: New best fitness = 23008000.00
# Generation 7: New best fitness = 20013600.00
# Generation 8: New best fitness = 19011800.00
# Generation 9: New best fitness = 16010800.00
# Generation 10: New best fitness = 14012200.00
# Generation 11: New best fitness = 11019200.00
# Generation 12: New best fitness = 11017200.00
# Generation 13: New best fitness = 10014200.00
# Generation 14: New best fitness = 8017400.00
# Generation 15: New best fitness = 6017200.00
# Generation 16: New best fitness = 6014200.00
# Generation 17: New best fitness = 4020200.00
# Generation 18: New best fitness = 4018600.00
# Generation 19: New best fitness = 3022200.00
# Generation 20: New best fitness = 3019200.00
# Generation 21: New best fitness = 2022200.00
# Generation 22: New best fitness = 2014200.00
# Generation 24: New best fitness = 21400.00
# Generation 26: New best fitness = 13000.00
# Generation 29: New best fitness = 9800.00
# Generation 33: New best fitness = 7800.00
# Generation 36: New best fitness = 6800.00
# Generation 40: New best fitness = 6600.00
# Generation 42: New best fitness = 5800.00
# Generation 43: New best fitness = 5600.00
# Generation 44: New best fitness = 4600.00
# Generation 46: New best fitness = 3800.00
# Generation 49: New best fitness = 3200.00
# Generation 51: New best fitness = 2800.00
# Generation 52: New best fitness = 2200.00
# Generation 56: New best fitness = 2000.00
# Generation 59: New best fitness = 1800.00
# Generation 86: New best fitness = 1600.00
# Generation 91: New best fitness = 600.00
# Generation 100, Best Fitness: 600.00, Time: 1.53s
# Generation 107: New best fitness = 400.00
# Generation 200, Best Fitness: 400.00, Time: 3.02s
# Generation 300, Best Fitness: 400.00, Time: 4.67s
# Generation 400, Best Fitness: 400.00, Time: 6.26s
# Generation 500, Best Fitness: 400.00, Time: 8.37s
# Generation 600, Best Fitness: 400.00, Time: 10.31s
# Generation 643: New best fitness = 200.00
# Generation 700, Best Fitness: 200.00, Time: 11.99s
# Generation 705: New best fitness = 0.00
# Perfect solution found! Generations: 705/10000, Fitness: 0
#
# Best schedule fitness: 0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Monday</th>
#       <th>Tuesday</th>
#       <th>Wednesday</th>
#     </tr>
#     <tr>
#       <th>Timeslot</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>08:00-09:30</th>
#       <td>Human Computer Interaction [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4<br>(NB111 (lecture))<br><br>Enterprise Systems and Network Administration [lab - 1] SG_Y4_IT<br>(NB114 (lab))<br><br></td>
#       <td>Fundamental of Electrical Circuits and Electronics [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4<br>(NB111 (lecture))<br><br></td>
#       <td>Machine Learning [lab - 1] SG_Y4_AI<br>(NB114 (lab))<br><br>Introduction to Robotics [lec - 1] SG_Y5_S1|SG_Y5_S2<br>(NB111 (lecture))<br><br></td>
#     </tr>
#     <tr>
#       <th>09:40-11:10</th>
#       <td>Web Design and Development [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4<br>(NB111 (lecture))<br><br></td>
#       <td>Fundamental of Electrical Circuits and Electronics [lab - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4<br>(NB114 (lab))<br><br>Enterprise Application Development [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2<br>(NB111 (lecture))<br><br></td>
#       <td>Software Project Management [lec - 2] SG_Y4_AI<br>(NB111 (lecture))<br><br>Big Data Modeling and Management System [lec - 1] SG_Y5_S1|SG_Y5_S2<br>(NB112 (lecture))<br><br></td>
#     </tr>
#     <tr>
#       <th>11:20-12:50</th>
#       <td>Introduction to Robotics and Intelligent Systems [lab - 1] SG_Y4_AI<br>(NB114 (lab))<br><br>E-business Strategy and Development [lec - 1] SG_Y4_IT<br>(NB111 (lecture))<br><br></td>
#       <td>Computer Architecture and Organization [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4<br>(NB111 (lecture))<br><br>Fundamentals of Distributed Systems [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2<br>(NB112 (lecture))<br><br>Introduction to Robotics [lab - 1] SG_Y5_S1|SG_Y5_S2<br>(NB114 (lab))<br><br></td>
#       <td>History of Ethiopia and the Horn [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2|SG_Y4_AI|SG_Y4_CY|SG_Y4_IT<br>(NB111 (lecture))<br><br></td>
#     </tr>
#     <tr>
#       <th>13:30-15:00</th>
#       <td>Fundamentals of Software Engineering [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4<br>(NB111 (lecture))<br><br>Enterprise Application Development [lab - 1] SG_Y4_SE_S1|SG_Y4_SE_S2<br>(NB114 (lab))<br><br>Mathematics for AI [lec - 1] SG_Y4_AI<br>(NB112 (lecture))<br><br></td>
#       <td>Software Project Management [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2<br>(NB112 (lecture))<br><br>Machine Learning [lec - 1] SG_Y4_AI<br>(NB111 (lecture))<br><br></td>
#       <td>Fundamentals of Software Engineering [lab - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4<br>(NB114 (lab))<br><br>Introduction to Robotics and Intelligent Systems [lec - 1] SG_Y4_AI<br>(NB111 (lecture))<br><br>Cloud Computing Security [lec - 1] SG_Y4_CY<br>(NB112 (lecture))<br><br></td>
#     </tr>
#     <tr>
#       <th>15:10-16:40</th>
#       <td>Machine Learning and Big Data [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2|SG_Y4_CY<br>(NB111 (lecture))<br><br>Social Network Analysis [lec - 1] SG_Y4_AI<br>(NB112 (lecture))<br><br>Database Administration and Security [lab - 1] SG_Y4_IT<br>(NB114 (lab))<br><br></td>
#       <td>Requirement Engineering, Architecture and Design [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2<br>(NB111 (lecture))<br><br></td>
#       <td>Enterprise Systems and Network Security [lec - 1] SG_Y4_CY<br>(NB111 (lecture))<br><br>Enterprise Systems and Network Administration [lec - 1] SG_Y4_IT<br>(NB112 (lecture))<br><br></td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Monday</th>
#       <th>Tuesday</th>
#       <th>Wednesday</th>
#     </tr>
#     <tr>
#       <th>Timeslot</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>08:00-09:30</th>
#       <td>Free</td>
#       <td>Free</td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <th>09:40-11:10</th>
#       <td>Free</td>
#       <td>Enterprise Application Development [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2<br>(NB111 (lecture))<br><br></td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <th>11:20-12:50</th>
#       <td>Free</td>
#       <td>Fundamentals of Distributed Systems [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2<br>(NB112 (lecture))<br><br></td>
#       <td>History of Ethiopia and the Horn [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2|SG_Y4_AI|SG_Y4_CY|SG_Y4_IT<br>(NB111 (lecture))<br><br></td>
#     </tr>
#     <tr>
#       <th>13:30-15:00</th>
#       <td>Enterprise Application Development [lab - 1] SG_Y4_SE_S1|SG_Y4_SE_S2<br>(NB114 (lab))<br><br></td>
#       <td>Software Project Management [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2<br>(NB112 (lecture))<br><br></td>
#       <td>Free</td>
#     </tr>
#     <tr>
#       <th>15:10-16:40</th>
#       <td>Machine Learning and Big Data [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2|SG_Y4_CY<br>(NB111 (lecture))<br><br></td>
#       <td>Requirement Engineering, Architecture and Design [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2<br>(NB111 (lecture))<br><br></td>
#       <td>Free</td>
#     </tr>
#   </tbody>
# </table>

# %%
res
# Out:
# [ScheduledItem(courseId='7', courseName='Fundamental of Electrical Circuits and Electronics [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4', sessionType='lecture', teacherId='1', studentGroupIds=['SG_Y3_SE_S1', 'SG_Y3_SE_S2', 'SG_Y3_SE_S3', 'SG_Y3_SE_S4'], classroomId='1', timeslot='13:30-15:00', day='Friday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='7', courseName='Fundamental of Electrical Circuits and Electronics [lab - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4', sessionType='lab', teacherId='1', studentGroupIds=['SG_Y3_SE_S1', 'SG_Y3_SE_S2', 'SG_Y3_SE_S3', 'SG_Y3_SE_S4'], classroomId='4', timeslot='11:20-12:50', day='Monday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='8', courseName='Computer Architecture and Organization [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4', sessionType='lecture', teacherId='1', studentGroupIds=['SG_Y3_SE_S1', 'SG_Y3_SE_S2', 'SG_Y3_SE_S3', 'SG_Y3_SE_S4'], classroomId='1', timeslot='', day='Wednesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='9', courseName='Web Design and Development [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4', sessionType='lecture', teacherId='2', studentGroupIds=['SG_Y3_SE_S1', 'SG_Y3_SE_S2', 'SG_Y3_SE_S3', 'SG_Y3_SE_S4'], classroomId='1', timeslot='', day='Friday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='9', courseName='Web Design and Development [lab - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4', sessionType='lab', teacherId='2', studentGroupIds=['SG_Y3_SE_S1', 'SG_Y3_SE_S2', 'SG_Y3_SE_S3', 'SG_Y3_SE_S4'], classroomId='4', timeslot='09:40-11:10', day='', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='10', courseName='Human Computer Interaction [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4', sessionType='lecture', teacherId='1', studentGroupIds=['SG_Y3_SE_S1', 'SG_Y3_SE_S2', 'SG_Y3_SE_S3', 'SG_Y3_SE_S4'], classroomId='1', timeslot='15:10-16:40', day='Thursday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='11', courseName='Fundamentals of Software Engineering [lec - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4', sessionType='lecture', teacherId='3', studentGroupIds=['SG_Y3_SE_S1', 'SG_Y3_SE_S2', 'SG_Y3_SE_S3', 'SG_Y3_SE_S4'], classroomId='1', timeslot='09:40-11:10', day='Tuesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='11', courseName='Fundamentals of Software Engineering [lab - 1] SG_Y3_SE_S1|SG_Y3_SE_S2|SG_Y3_SE_S3|SG_Y3_SE_S4', sessionType='lab', teacherId='3', studentGroupIds=['SG_Y3_SE_S1', 'SG_Y3_SE_S2', 'SG_Y3_SE_S3', 'SG_Y3_SE_S4'], classroomId='4', timeslot='11:20-12:50', day='Thursday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='12', courseName='Software Project Management [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2', sessionType='lecture', teacherId='1', studentGroupIds=['SG_Y4_SE_S1', 'SG_Y4_SE_S2'], classroomId='1', timeslot='11:20-12:50', day='Thursday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='12', courseName='Software Project Management [lec - 2] SG_Y4_AI', sessionType='lecture', teacherId='1', studentGroupIds=['SG_Y4_AI'], classroomId='1', timeslot='11:20-12:50', day='Tuesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='13', courseName='Enterprise Application Development [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2', sessionType='lecture', teacherId='2', studentGroupIds=['SG_Y4_SE_S1', 'SG_Y4_SE_S2'], classroomId='2', timeslot='08:00-09:30', day='Friday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='13', courseName='Enterprise Application Development [lab - 1] SG_Y4_SE_S1|SG_Y4_SE_S2', sessionType='lab', teacherId='2', studentGroupIds=['SG_Y4_SE_S1', 'SG_Y4_SE_S2'], classroomId='4', timeslot='15:10-16:40', day='Tuesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='14', courseName='Requirement Engineering, Architecture and Design [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2', sessionType='lecture', teacherId='3', studentGroupIds=['SG_Y4_SE_S1', 'SG_Y4_SE_S2'], classroomId='2', timeslot='15:10-16:40', day='Wednesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='15', courseName='History of Ethiopia and the Horn [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2|SG_Y4_AI|SG_Y4_CY|SG_Y4_IT', sessionType='lecture', teacherId='4', studentGroupIds=['SG_Y4_SE_S1', 'SG_Y4_SE_S2', 'SG_Y4_AI', 'SG_Y4_CY', 'SG_Y4_IT'], classroomId='1', timeslot='15:10-16:40', day='Friday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='16', courseName='Fundamentals of Distributed Systems [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2', sessionType='lecture', teacherId='2', studentGroupIds=['SG_Y4_SE_S1', 'SG_Y4_SE_S2'], classroomId='1', timeslot='13:30-15:00', day='Wednesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='17', courseName='Machine Learning and Big Data [lec - 1] SG_Y4_SE_S1|SG_Y4_SE_S2|SG_Y4_CY', sessionType='lecture', teacherId='5', studentGroupIds=['SG_Y4_SE_S1', 'SG_Y4_SE_S2', 'SG_Y4_CY'], classroomId='1', timeslot='09:40-11:10', day='', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='17', courseName='Machine Learning and Big Data [lab - 1] SG_Y4_SE_S1|SG_Y4_SE_S2|SG_Y4_CY', sessionType='lab', teacherId='5', studentGroupIds=['SG_Y4_SE_S1', 'SG_Y4_SE_S2', 'SG_Y4_CY'], classroomId='4', timeslot='13:30-15:00', day='Friday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='18', courseName='Machine Learning [lec - 1] SG_Y4_AI', sessionType='lecture', teacherId='5', studentGroupIds=['SG_Y4_AI'], classroomId='2', timeslot='13:30-15:00', day='Thursday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='18', courseName='Machine Learning [lab - 1] SG_Y4_AI', sessionType='lab', teacherId='5', studentGroupIds=['SG_Y4_AI'], classroomId='4', timeslot='15:10-16:40', day='Thursday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='19', courseName='Social Network Analysis [lec - 1] SG_Y4_AI', sessionType='lecture', teacherId='6', studentGroupIds=['SG_Y4_AI'], classroomId='2', timeslot='09:40-11:10', day='Friday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='20', courseName='Mathematics for AI [lec - 1] SG_Y4_AI', sessionType='lecture', teacherId='6', studentGroupIds=['SG_Y4_AI'], classroomId='2', timeslot='08:00-09:30', day='Tuesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='21', courseName='Introduction to Robotics and Intelligent Systems [lec - 1] SG_Y4_AI', sessionType='lecture', teacherId='7', studentGroupIds=['SG_Y4_AI'], classroomId='1', timeslot='08:00-09:30', day='Thursday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='21', courseName='Introduction to Robotics and Intelligent Systems [lab - 1] SG_Y4_AI', sessionType='lab', teacherId='7', studentGroupIds=['SG_Y4_AI'], classroomId='4', timeslot='', day='', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='23', courseName='Enterprise Systems and Network Security [lec - 1] SG_Y4_CY', sessionType='lecture', teacherId='7', studentGroupIds=['SG_Y4_CY'], classroomId='1', timeslot='09:40-11:10', day='Wednesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='23', courseName='Enterprise Systems and Network Security [lab - 1] SG_Y4_CY', sessionType='lab', teacherId='7', studentGroupIds=['SG_Y4_CY'], classroomId='4', timeslot='11:20-12:50', day='Friday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='24', courseName='Cloud Computing Security [lec - 1] SG_Y4_CY', sessionType='lecture', teacherId='8', studentGroupIds=['SG_Y4_CY'], classroomId='1', timeslot='13:30-15:00', day='Monday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='25', courseName='Enterprise Systems and Network Administration [lec - 1] SG_Y4_IT', sessionType='lecture', teacherId='8', studentGroupIds=['SG_Y4_IT'], classroomId='2', timeslot='11:20-12:50', day='Thursday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='25', courseName='Enterprise Systems and Network Administration [lab - 1] SG_Y4_IT', sessionType='lab', teacherId='8', studentGroupIds=['SG_Y4_IT'], classroomId='4', timeslot='13:30-15:00', day='Tuesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='26', courseName='E-business Strategy and Development [lec - 1] SG_Y4_IT', sessionType='lecture', teacherId='9', studentGroupIds=['SG_Y4_IT'], classroomId='2', timeslot='11:20-12:50', day='Friday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='27', courseName='Database Administration and Security [lec - 1] SG_Y4_IT', sessionType='lecture', teacherId='8', studentGroupIds=['SG_Y4_IT'], classroomId='1', timeslot='', day='', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='27', courseName='Database Administration and Security [lab - 1] SG_Y4_IT', sessionType='lab', teacherId='8', studentGroupIds=['SG_Y4_IT'], classroomId='4', timeslot='15:10-16:40', day='Monday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='28', courseName='Big Data Modeling and Management System [lec - 1] SG_Y5_S1|SG_Y5_S2', sessionType='lecture', teacherId='7', studentGroupIds=['SG_Y5_S1', 'SG_Y5_S2'], classroomId='2', timeslot='15:10-16:40', day='Monday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='29', courseName='Distributed and Object Database [lec - 1] SG_Y5_S1|SG_Y5_S2', sessionType='lecture', teacherId='2', studentGroupIds=['SG_Y5_S1', 'SG_Y5_S2'], classroomId='2', timeslot='13:30-15:00', day='Tuesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='29', courseName='Distributed and Object Database [lab - 1] SG_Y5_S1|SG_Y5_S2', sessionType='lab', teacherId='2', studentGroupIds=['SG_Y5_S1', 'SG_Y5_S2'], classroomId='4', timeslot='09:40-11:10', day='Friday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='30', courseName='Introduction to Robotics [lec - 1] SG_Y5_S1|SG_Y5_S2', sessionType='lecture', teacherId='6', studentGroupIds=['SG_Y5_S1', 'SG_Y5_S2'], classroomId='2', timeslot='09:40-11:10', day='Wednesday', is_valid_hard=True, is_valid_soft=True),
#  ScheduledItem(courseId='30', courseName='Introduction to Robotics [lab - 1] SG_Y5_S1|SG_Y5_S2', sessionType='lab', teacherId='6', studentGroupIds=['SG_Y5_S1', 'SG_Y5_S2'], classroomId='4', timeslot='09:40-11:10', day='Tuesday', is_valid_hard=True, is_valid_soft=True)]
